# %% [markdown]
# # Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading Dataset

# %%
df=pd.read_csv('hr_train.csv')

# %% [markdown]
# # Checking the basic details of the dataset

# %%
df.head()
# Out:
#    EmployeeNumber  satisfaction_level  last_evaluation  number_project  \
# 0               1                0.42             0.46               2
# 1               2                0.66             0.77               2
# 2               3                0.55             0.49               5
# 3               4                0.22             0.88               4
# 4               5                0.20             0.72               6
#
#    average_montly_hours  time_spend_company  Work_accident  left  \
# 0                   150                   3              0     1
# 1                   171                   2              0     0
# 2                   240                   3              0     0
# 3                   213                   3              1     0
# 4                   224                   4              0     1
#
#    promotion_last_5years      sales  ... Age  Gender MaritalStatus OverTime  \
# ...

# %%
df.tail()
# Out:
#       EmployeeNumber  satisfaction_level  last_evaluation  number_project  \
# 9995            9996                0.81             0.90               4
# 9996            9997                0.69             0.50               3
# 9997            9998                0.49             0.83               3
# 9998            9999                0.90             0.64               4
# 9999           10000                0.43             0.51               2
#
#       average_montly_hours  time_spend_company  Work_accident  left  \
# 9995                   270                  10              0     0
# 9996                   208                   4              0     0
# 9997                   168                   4              1     0
# 9998                   209                   4              0     0
# 9999                   128                   3              0     1
#
#       promotion_last_5years       sales  ... Age  Gender MaritalStatus  \
# ...

# %%
df.shape
# Out:
# (10000, 21)

# %%
df.dtypes
# Out:
# EmployeeNumber               int64
# satisfaction_level         float64
# last_evaluation            float64
# number_project               int64
# average_montly_hours         int64
# time_spend_company           int64
# Work_accident                int64
# left                         int64
# promotion_last_5years        int64
# sales                       object
# salary                      object
# Age                          int64
# Gender                      object
# MaritalStatus               object
# OverTime                    object
# BusinessTravel              object
# JobLevel                     int64
# Education                    int64
# EnvironmentSatisfaction      int64
# NumCompaniesWorked           int64
# Over18                      object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeNumber           10000 non-null  int64
#  1   satisfaction_level       10000 non-null  float64
#  2   last_evaluation          10000 non-null  float64
#  3   number_project           10000 non-null  int64
#  4   average_montly_hours     10000 non-null  int64
#  5   time_spend_company       10000 non-null  int64
#  6   Work_accident            10000 non-null  int64
#  7   left                     10000 non-null  int64
#  8   promotion_last_5years    10000 non-null  int64
#  9   sales                    10000 non-null  object
#  10  salary                   10000 non-null  object
#  11  Age                      10000 non-null  int64
#  12  Gender                   10000 non-null  object
#  13  MaritalStatus            10000 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['EmployeeNumber', 'satisfaction_level', 'last_evaluation',
#        'number_project', 'average_montly_hours', 'time_spend_company',
#        'Work_accident', 'left', 'promotion_last_5years', 'sales', 'salary',
#        'Age', 'Gender', 'MaritalStatus', 'OverTime', 'BusinessTravel',
#        'JobLevel', 'Education', 'EnvironmentSatisfaction',
#        'NumCompaniesWorked', 'Over18'],
#       dtype='object')

# %% [markdown]
# # Data Preprocessing

# %% [raw]
# 1.Checking the missing values

# %%
 df.isna().sum()
# Out:
# EmployeeNumber             0
# satisfaction_level         0
# last_evaluation            0
# number_project             0
# average_montly_hours       0
# time_spend_company         0
# Work_accident              0
# left                       0
# promotion_last_5years      0
# sales                      0
# salary                     0
# Age                        0
# Gender                     0
# MaritalStatus              0
# OverTime                   0
# BusinessTravel             0
# JobLevel                   0
# Education                  0
# EnvironmentSatisfaction    0
# NumCompaniesWorked         0
# Over18                     0
# dtype: int64

# %% [raw]
# 2.Outlier detection and handling

# %%
plt.boxplot(df['Age'])
plt.title('Box plot for Age')
# Out:
# Text(0.5, 1.0, 'Box plot for Age')

# %%
plt.boxplot(df['Education'])
plt.title('Box plot for Education')
# Out:
# Text(0.5, 1.0, 'Box plot for Education')

# %%
plt.boxplot(df['JobLevel'])
plt.title('Box plot for JobLevel')
# Out:
# Text(0.5, 1.0, 'Box plot for JobLevel')

# %% [raw]
# 3.Encoding(Label Encoding)

# %%
from sklearn.preprocessing import LabelEncoder

x = x.apply(LabelEncoder().fit_transform)
y = y.apply(LabelEncoder().fit_transform)

# %%
df.head()
# Out:
#    EmployeeNumber  satisfaction_level  last_evaluation  number_project  \
# 0               1                0.42             0.46               2
# 1               2                0.66             0.77               2
# 2               3                0.55             0.49               5
# 3               4                0.22             0.88               4
# 4               5                0.20             0.72               6
#
#    average_montly_hours  time_spend_company  Work_accident  left  \
# 0                   150                   3              0     1
# 1                   171                   2              0     0
# 2                   240                   3              0     0
# 3                   213                   3              1     0
# 4                   224                   4              0     1
#
#    promotion_last_5years      sales  ... Age  Gender MaritalStatus OverTime  \
# ...

# %% [raw]
# 4.Feature Reduction

# %%
corrmatrix=df.corr()
plt.subplots(figsize=(20,8))
sns.heatmap(corrmatrix,vmin=-0.4,vmax=0.9,annot=True,linewidths=0.2)
# Out:
# <AxesSubplot:>

# %% [raw]
# 5.Feature Engineering

# %%
df.columns
# Out:
# Index(['EmployeeNumber', 'satisfaction_level', 'last_evaluation',
#        'number_project', 'average_montly_hours', 'time_spend_company',
#        'Work_accident', 'left', 'promotion_last_5years', 'sales', 'salary',
#        'Age', 'Gender', 'MaritalStatus', 'OverTime', 'BusinessTravel',
#        'JobLevel', 'Education', 'EnvironmentSatisfaction',
#        'NumCompaniesWorked', 'Over18'],
#       dtype='object')

# %%
df = df.drop('EmployeeNumber',axis=1)
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.42             0.46               2                   150
# 1                0.66             0.77               2                   171
# 2                0.55             0.49               5                   240
# 3                0.22             0.88               4                   213
# 4                0.20             0.72               6                   224
#
#    time_spend_company  Work_accident  left  promotion_last_5years      sales  \
# 0                   3              0     1                      0      sales
# 1                   2              0     0                      0  technical
# 2                   3              0     0                      0  technical
# 3                   3              1     0                      0  technical
# 4                   4              0     1                      0  technical
#
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [raw]
# We shall first do the Univariate Analysis by analysing the data w.r.t our Target Variable - left.

# %%
Target = 'left'
pd.crosstab(df[Target], columns = 'Normalized', normalize = True)
# Out:
# col_0  Normalized
# left
# 0          0.7078
# 1          0.2922

# %% [markdown]
# We have approximately 70% of 0's and 29% of 1's in our data

# %% [markdown]
# # **Univariate Analysis**

# %% [markdown]
# ### salary

# %%
print("Unique values salary count: ", df['salary'].nunique())
print("salary values: ", df['salary'].unique())
pd.value_counts(df['salary'])
# Out:
# Unique values salary count:  3
# salary values:  ['medium' 'high' 'low']
# low       4864
# medium    4294
# high       842
# Name: salary, dtype: int64

# %%
plt.figure(figsize = (6,4))
plt.pie(pd.value_counts(df['salary']), labels = ['medium','high','low'],autopct = '%.2f%%',textprops = {'size' : 'x-large','fontweight' : 'bold', 'rotation' : '30','color' : 'w'})
plt.legend()
plt.title('Percentage Of salary', fontsize = 18, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### BusinessTravel

# %%
print("Unique values BusinessTravel count: ", df['BusinessTravel'].nunique())
print("BusinessTravel values: ", df['BusinessTravel'].unique())
pd.value_counts(df['BusinessTravel'])
# Out:
# Unique values BusinessTravel count:  3
# BusinessTravel values:  ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Travel_Rarely        3370
# Non-Travel           3343
# Travel_Frequently    3287
# Name: BusinessTravel, dtype: int64

# %%
plt.figure(figsize = (6,4))
plt.pie(pd.value_counts(df['BusinessTravel']), labels = ['Travel_Rarely','Travel_Frequently','Non-Travel'],autopct = '%.2f%%',textprops = {'size' : 'x-large','fontweight' : 'bold', 'rotation' : '30','color' : 'w'})
plt.legend()
plt.title('Percentage Of BusinessTravel', fontsize = 18, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### Gender

# %%
print("Unique values Gender count: ", df['Gender'].nunique())
print("Gender values: ", df['Gender'].unique())
pd.value_counts(df['Gender'])
# Out:
# Unique values Gender count:  2
# Gender values:  ['Male' 'Female']
# Male      5019
# Female    4981
# Name: Gender, dtype: int64

# %%
plt.figure(figsize = (6,4))
plt.pie(pd.value_counts(df['Gender']), labels = ['Male','Female'],autopct = '%.2f%%',textprops = {'size' : 'x-large','fontweight' : 'bold', 'rotation' : '30','color' : 'w'})
plt.legend()
plt.title('Percentage Of Gender', fontsize = 18, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### MaritalStatus

# %%
print("Unique values MaritalStatus count: ", df['MaritalStatus'].nunique())
print("MaritalStatus values: ", df['MaritalStatus'].unique())
pd.value_counts(df['MaritalStatus'])
# Out:
# Unique values MaritalStatus count:  3
# MaritalStatus values:  ['Single' 'Divorced' 'Married']
# Divorced    3427
# Single      3296
# Married     3277
# Name: MaritalStatus, dtype: int64

# %%
plt.figure(figsize = (6,4))
plt.pie(pd.value_counts(df['MaritalStatus']), labels = ['Single','Divorced','Married'],autopct = '%.2f%%',textprops = {'size' : 'x-large','fontweight' : 'bold', 'rotation' : '30','color' : 'w'})
plt.legend()
plt.title('Percentage Of MaritalStatus', fontsize = 18, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### Work_accident

# %%
print("Unique values Work_accident count: ", df['Work_accident'].nunique())
print("Work_accident values: ", df['Work_accident'].unique())
pd.value_counts(df['Work_accident'])
# Out:
# Unique values Work_accident count:  2
# Work_accident values:  [0 1]
# 0    8570
# 1    1430
# Name: Work_accident, dtype: int64

# %%
plt.figure(figsize = (6,4))
plt.pie(pd.value_counts(df['Work_accident']), labels = [0,1],autopct = '%.2f%%',textprops = {'size' : 'x-large','fontweight' : 'bold', 'rotation' : '30','color' : 'w'})
plt.legend()
plt.title('Percentage Of Work_accident', fontsize = 18, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### time_spend_company

# %%
print("Unique values time_spend_company count: ", df['time_spend_company'].nunique())
print("time_spend_company values: ", df['time_spend_company'].unique())
pd.value_counts(df['time_spend_company'])
# Out:
# Unique values time_spend_company count:  8
# time_spend_company values:  [ 3  2  4  5  6  8  7 10]
# 3     4244
# 2     2184
# 4     1726
# 5      987
# 6      486
# 10     137
# 7      128
# 8      108
# Name: time_spend_company, dtype: int64

# %%
plt.figure(figsize = (6,4))
plt.pie(pd.value_counts(df['time_spend_company']), labels = ['Male','Female'],autopct = '%.2f%%',textprops = {'size' : 'x-large','fontweight' : 'bold', 'rotation' : '30','color' : 'w'})
plt.legend()
plt.title('Percentage Of time_spend_company', fontsize = 18, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### OverTime

# %%
print("Unique values OverTime count: ", df['OverTime'].nunique())
print("Gender values: ", df['OverTime'].unique())
pd.value_counts(df['OverTime'])
# Out:
# Unique values OverTime count:  2
# Gender values:  ['Yes' 'No']
# No     5016
# Yes    4984
# Name: OverTime, dtype: int64

# %%
plt.figure(figsize = (6,4))
plt.pie(pd.value_counts(df['OverTime']), labels = ['Yes','No'],autopct = '%.2f%%',textprops = {'size' : 'x-large','fontweight' : 'bold', 'rotation' : '30','color' : 'w'})
plt.legend()
plt.title('Percentage Of OverTime', fontsize = 18, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### number_project

# %%
print("Unique values number_project count: ", df['number_project'].nunique())
print("number_project values: ", df['number_project'].unique())
pd.value_counts(df['number_project'])
# Out:
# Unique values number_project count:  6
# number_project values:  [2 5 4 6 3 7]
# 4    2913
# 3    2678
# 5    1905
# 2    1560
# 6     773
# 7     171
# Name: number_project, dtype: int64

# %%
plt.figure(figsize = (6,4))
plt.pie(pd.value_counts(df['number_project']), labels = [2,5,4,6,3,7],autopct = '%.2f%%',textprops = {'size' : 'x-large','fontweight' : 'bold', 'rotation' : '30','color' : 'w'})
plt.legend()
plt.title('Percentage Of number_project', fontsize = 18, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### sales

# %%
print("Unique values sales count: ", df['sales'].nunique())
print("sales values: ", df['sales'].unique())
pd.value_counts(df['sales'])
# Out:
# Unique values sales count:  10
# sales values:  ['sales' 'technical' 'product_mng' 'marketing' 'IT' 'RandD' 'hr'
#  'accounting' 'support' 'management']
# sales          2805
# technical      1793
# support        1487
# IT              776
# product_mng     609
# marketing       582
# RandD           510
# hr              510
# accounting      500
# management      428
# Name: sales, dtype: int64

# %%
plt.figure(figsize = (6,4))
plt.pie(pd.value_counts(df['sales']), labels = ['sales','technical','product_mng','marketing','IT','RandD','hr','accounting','support','management'],autopct = '%.2f%%',textprops = {'size' : 'x-large','fontweight' : 'bold', 'rotation' : '30','color' : 'w'})
plt.legend()
plt.title('Percentage Of sales', fontsize = 18, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### JobLevel

# %%
print("Unique values JobLevel count: ", df['JobLevel'].nunique())
print("JobLevel values: ", df['JobLevel'].unique())
pd.value_counts(df['JobLevel'])
# Out:
# Unique values JobLevel count:  5
# JobLevel values:  [1 2 4 5 3]
# 4    2097
# 2    2029
# 3    1990
# 1    1942
# 5    1942
# Name: JobLevel, dtype: int64

# %%
plt.figure(figsize = (6,4))
plt.pie(pd.value_counts(df['JobLevel']), labels = [1,2,3,4,5],autopct = '%.2f%%',textprops = {'size' : 'x-large','fontweight' : 'bold', 'rotation' : '30','color' : 'w'})
plt.legend()
plt.title('Percentage Of JobLevel', fontsize = 18, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### Education

# %%
print("Unique values Education count: ", df['Education'].nunique())
print("Education values: ", df['Education'].unique())
pd.value_counts(df['Education'])
# Out:
# Unique values Education count:  5
# Education values:  [5 1 3 2 4]
# 1    2069
# 2    2024
# 4    1995
# 3    1961
# 5    1951
# Name: Education, dtype: int64

# %%
plt.figure(figsize = (6,4))
plt.pie(pd.value_counts(df['Education']), labels = [1,2,3,4,5],autopct = '%.2f%%',textprops = {'size' : 'x-large','fontweight' : 'bold', 'rotation' : '30','color' : 'w'})
plt.legend()
plt.title('Education', fontsize = 18, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### EnvironmentSatisfaction

# %%
print("Unique values EnvironmentSatisfaction count: ", df['EnvironmentSatisfaction'].nunique())
print("EnvironmentSatisfaction values: ", df['EnvironmentSatisfaction'].unique())
pd.value_counts(df['EnvironmentSatisfaction'])
# Out:
# Unique values EnvironmentSatisfaction count:  4
# EnvironmentSatisfaction values:  [3 2 1 4]
# 1    2520
# 2    2512
# 3    2494
# 4    2474
# Name: EnvironmentSatisfaction, dtype: int64

# %%
plt.figure(figsize = (6,4))
plt.pie(pd.value_counts(df['EnvironmentSatisfaction']), labels = [1,2,3,4],autopct = '%.2f%%',textprops = {'size' : 'x-large','fontweight' : 'bold', 'rotation' : '30','color' : 'w'})
plt.legend()
plt.title('Percentage Of EnvironmentSatisfaction', fontsize = 18, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### NumCompaniesWorked

# %%
print("Unique values NumCompaniesWorked count: ", df['NumCompaniesWorked'].nunique())
print("NumCompaniesWorked values: ", df['NumCompaniesWorked'].unique())
pd.value_counts(df['NumCompaniesWorked'])
# Out:
# Unique values NumCompaniesWorked count:  9
# NumCompaniesWorked values:  [2 6 5 3 0 4 7 1 8]
# 2    1145
# 7    1132
# 8    1132
# 1    1118
# 3    1111
# 6    1108
# 4    1101
# 0    1100
# 5    1053
# Name: NumCompaniesWorked, dtype: int64

# %%
plt.figure(figsize = (6,4))
plt.pie(pd.value_counts(df['NumCompaniesWorked']), labels = [0,1,2,3,4,5,6,7,8],autopct = '%.2f%%',textprops = {'size' : 'x-large','fontweight' : 'bold', 'rotation' : '30','color' : 'w'})
plt.legend()
plt.title('NumCompaniesWorked', fontsize = 18, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### satisfaction_level

# %%
df['satisfaction_level'].value_counts()
# Out:
# 0.10    245
# 0.11    226
# 0.74    187
# 0.73    172
# 0.76    171
#        ...
# 0.35     20
# 0.25     19
# 0.27     18
# 0.12     17
# 0.26     14
# Name: satisfaction_level, Length: 92, dtype: int64

# %%
df['satisfaction_level'].value_counts().hist(color='r')
plt.title('satisfaction_level', fontsize = 18, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### last_evaluation

# %%
df['last_evaluation'].value_counts()
# Out:
# 0.55    249
# 0.51    238
# 0.50    233
# 0.54    221
# 0.52    218
#        ...
# 0.42     37
# 0.43     32
# 0.44     28
# 0.39     27
# 0.36     13
# Name: last_evaluation, Length: 65, dtype: int64

# %%
df['last_evaluation'].value_counts().hist(color='r')
plt.title('last_evaluation', fontsize = 18, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### average_montly_hours

# %%
df['average_montly_hours'].value_counts()
# Out:
# 151    109
# 156    105
# 135     98
# 149     97
# 160     97
#       ...
# 288      4
# 299      4
# 303      4
# 96       3
# 302      3
# Name: average_montly_hours, Length: 215, dtype: int64

# %%
df['average_montly_hours'].value_counts().hist(color='g')
plt.title('average_montly_hours', fontsize = 18, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### Age

# %%
df['Age'].value_counts()
# Out:
# 48    260
# 21    259
# 57    255
# 28    254
# 60    254
# 41    252
# 33    249
# 56    248
# 26    248
# 39    246
# 31    246
# 55    243
# 46    242
# 50    242
# 24    240
# 49    239
# 18    238
# 23    238
# 34    237
# 29    235
# 58    235
# 22    234
# 54    234
# 51    234
# 27    232
# 43    231
# 45    225
# 19    225
# 25    225
# 42    222
# 30    221
# 36    220
# 53    219
# 38    219
# 35    218
# 37    218
# 47    218
# 40    217
# 52    217
# 59    213
# 20    209
# 32    199
# 44    190
# Name: Age, dtype: int64

# %%
df['Age'].value_counts().hist(color='m')
plt.title('Age', fontsize = 18, fontweight = 'bold')
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %% [raw]
# We would categorize the existing variables of our existing dataframe into numerical and categorical variables.

# %%
num_cols = df.select_dtypes(include = [np.number]).columns.tolist()
obj_cols = df.select_dtypes(exclude = [np.number]).columns.tolist()

# %% [raw]
# Let's drop the columns which we won't be using

# %%
num_cols = df.drop(['left'], axis = 1).select_dtypes(include = [np.number]).columns.tolist()

# %%
print('Numeric Columns \n', num_cols)
print('Non-Numeric Columns \n', obj_cols)
# Out:
# Numeric Columns
#  ['satisfaction_level', 'last_evaluation', 'number_project', 'average_montly_hours', 'time_spend_company', 'Work_accident', 'promotion_last_5years', 'Age', 'JobLevel', 'Education', 'EnvironmentSatisfaction', 'NumCompaniesWorked']
# Non-Numeric Columns
#  ['sales', 'salary', 'Gender', 'MaritalStatus', 'OverTime', 'BusinessTravel', 'Over18']

# %% [raw]
# Analysis of each category of the categorical variables of obj_cols dataframe w.r.t Target variable - left.

# %%
obj_cols_viz = obj_cols + ['number_project','time_spend_company', 'Work_accident', 'promotion_last_5years', 'JobLevel', 'Education', 'EnvironmentSatisfaction', 'NumCompaniesWorked']
fig, axes = plt.subplots(len(obj_cols_viz), sharex = False, sharey = False, figsize = (25,50))
for i in range(0, len(obj_cols_viz)):
    pd.crosstab(df[obj_cols_viz[i]], df[Target]).plot(kind = 'bar', stacked = True, grid = False, ax = axes[i])
